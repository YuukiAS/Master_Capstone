# %%
import sqlite3
from xml.etree.ElementTree import ParseError
from tqdm import tqdm
import os
import sys
sys.path.append("../..")

import importlib
module = importlib.import_module('utils.ecg_utils')
importlib.reload(module)
from utils.ecg_utils import parse_date, plot_ecg_signal

# %%
import importlib
module = importlib.import_module("utils.ecg_utils")
importlib.reload(module)
# Out:
# <module 'utils.ecg_utils' from '/work/users/y/u/yuukias/BIOS-Material/BIOS992/script/../utils/ecg_utils.py'>

# %%
ECG_folder = "/users/y/u/yuukias/database/UKBiobank/6025"

# %% [markdown]
# ## Time of ECG Recording

# %%
from utils.constants import db_file, processed_table_name, primary_key

# create a column to store the date of the ECG recording

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# %%
update_sql = f"""
    ALTER TABLE {processed_table_name}
    ADD COLUMN ECG_date DATE;
"""

cursor.execute(update_sql)

for file_path in tqdm(sorted(os.listdir(ECG_folder))):
    if file_path.endswith(".xml"):
        eid = file_path.split("_")[0]
        file_path = os.path.join(ECG_folder, file_path)
        try:
            date = parse_date(file_path)
            cursor.execute(f"UPDATE {processed_table_name} SET ECG_date = ? WHERE {primary_key} = ?", (date, eid))
        except ParseError:
            continue

conn.commit()
# Out:
#   0%|          | 0/77888 [00:00<?, ?it/s]
# 100%|██████████| 77888/77888 [2:21:53<00:00,  9.15it/s]

# %%
# Determine how many participants who have ECG date.
query_sql = f"SELECT COUNT(*) FROM {processed_table_name} WHERE ECG_date IS NOT NULL;"
cursor.execute(query_sql)
print(cursor.fetchall())

query_sql = f"SELECT COUNT(*) FROM {processed_table_name} WHERE ECG_date IS NOT NULL AND test_status = 1;"
cursor.execute(query_sql)
print(cursor.fetchall())

# Also calculate for participants with and without CVD respectively
query_sql = f"SELECT COUNT(*) FROM {processed_table_name} WHERE ECG_date IS NOT NULL AND CVD = 1  AND test_status = 1;"
cursor.execute(query_sql)
print(cursor.fetchall())

query_sql = f"SELECT COUNT(*) FROM {processed_table_name} WHERE ECG_date IS NOT NULL AND CVD = 0  AND test_status = 1;"
cursor.execute(query_sql)
print(cursor.fetchall())
# Out:
# [(61927,)]
# [(49608,)]
# [(9077,)]
# [(40531,)]

# %% [markdown]
# There are 15691 participants with ECG XML that are empty. The remaining 61927 can be used for the analysis.

# %% [markdown]
# # Main extractable variables

# %% [markdown]
# We will only use the maximum HR and maximum workload, which have already been provided in UK Biobank in field 6032 and 6033. Check https://biobank.ndph.ox.ac.uk/ukb/label.cgi?id=100012

# %% [markdown]
# # HRV indices

# %%
import importlib
module = importlib.import_module('utils.ecg_processor')
importlib.reload(module)
import numpy as np
from utils.ecg_processor import ECG_Processor

# %%
SAMPLING_RATE = 500
ID = "1000668"

# %% [markdown]
# We first test whether HRV nonlinear indices can be extracted.

# %%
ecg_processor = ECG_Processor(ECG_folder, ID)
# Out:
# Lead order: ['I', '2', '3']

# %%
signal_fragment1 = ecg_processor.get_signals('2')[:1000]
signal_fragment2 = ecg_processor.get_signals('2')[-1000:]

# %%
plot_ecg_signal(signal_fragment1)
# Out:
# (<Figure size 2000x300 with 1 Axes>,
#  <AxesSubplot:xlabel='Time (ms)', ylabel='Amplitude'>)

# %%
plot_ecg_signal(signal_fragment2)
# Out:
# (<Figure size 2000x300 with 1 Axes>,
#  <AxesSubplot:xlabel='Time (ms)', ylabel='Amplitude'>)

# %% [markdown]
# Get relevant information from the database.

# %%
from utils.constants import db_file, variables_table_name, processed_table_name, primary_key

# create a column to store the date of the ECG recording

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# %%
query_sql = f"""
SELECT `5991-0.0`, `5991-0.1`, `5991-0.2`
FROM {variables_table_name}
LIMIT 10;
"""
cursor.execute(query_sql)
print(cursor.fetchall())
# Out:
# [('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest'), ('Pretest', 'Exercise', 'Rest')]

# %%
# phase name, array indices 0-2
query_sql = f"""
SELECT `5991-0.0`, `5991-0.1`, `5991-0.2` 
FROM {variables_table_name}
WHERE {primary_key} = {ID};
"""
cursor.execute(query_sql)
print(cursor.fetchall())


# phase duration, array indices 0-2
query_sql = f"""
SELECT `5992-0.0`, `5992-0.1`, `5992-0.2` 
FROM {variables_table_name}
WHERE {primary_key} = {ID};
"""
cursor.execute(query_sql)
print(cursor.fetchall())

# maximum workload (Watts) and maximum heart rate (beats per minute)
query_sql = f"""
SELECT `6032-0.0`, `6033-0.0`
FROM {variables_table_name}
WHERE {primary_key} = {ID};
"""
cursor.execute(query_sql)
print(cursor.fetchall())
# Out:
# [('Pretest', 'Exercise', 'Rest')]
# [(15.0, 360.0, 60.0)]
# [(70.0, 120.0)]

# %%
ecg_processor.get_info()
# Out:
# {'max_heart_rate': '120',
#  'max_workload': {'@units': 'watts', '#text': '70'},
#  'sampling_rate': 500}

# %% [markdown]
# This aligns with the information stored in the database.
#
# Now we count the number of participants with valid XML files.

# %%
query_schema_sql = f"""
PRAGMA table_info({variables_table_name});
"""
cursor.execute(query_schema_sql)
columns = cursor.fetchall()

# trend phase name (pretest, exericse, ...), array indices 0-113
columns_5987 = [f"`{col[1]}`" for col in columns if "5987" in col[1]]
columns_5987_str = ", ".join(columns_5987)
query_sql = f"""
SELECT {columns_5987_str}
FROM {variables_table_name}
WHERE {primary_key} = {ID};
"""
cursor.execute(query_sql)
phase_name_raw = cursor.fetchall()[0]

# stage name (steady, constant, ...), array indices 0-113
columns_5988 = [f"`{col[1]}`" for col in columns if "5988" in col[1]]
columns_5988_str = ", ".join(columns_5988)
query_sql = f"""
SELECT {columns_5988_str}
FROM {variables_table_name}
WHERE {primary_key} = {ID};
"""
cursor.execute(query_sql)
stage_name_raw = cursor.fetchall()[0]

# %%
phase_name = [name for name in phase_name_raw if name and name != 'nan']
stage_name = [name for name in stage_name_raw if name and name != 'nan']
print(len(phase_name), phase_name)
print(len(stage_name), stage_name)
# Out:
# 81 ['Pretest', 'Pretest', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest']
# 81 ['Steady', 'Steady', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Ramp1', 'Ramp1', 'Ramp2', 'Ramp2', 'Ramp3', 'Ramp3', 'Ramp3', 'Ramp4', 'Ramp4', 'Ramp5', 'Ramp5', 'Ramp6', 'Ramp6', 'Ramp6', 'Ramp7', 'Ramp7', 'Ramp8', 'Ramp8', 'Ramp9', 'Ramp9', 'Ramp9', 'Ramp9', 'Ramp10', 'Ramp10', 'Ramp11', 'Ramp11', 'Ramp12', 'Ramp12', 'Ramp12', 'Ramp13', 'Ramp13', 'Ramp13', 'Ramp14', 'Ramp14', 'Ramp15', 'Ramp15', 'Ramp15', 'Ramp16', 'Ramp16', 'Ramp17', 'Ramp17', 'Ramp18', 'Ramp18', 'Ramp18', 'Ramp18', 'Ramp19', 'Ramp19', 'Ramp20', 'Ramp20', 'Ramp21', 'Ramp21', 'Ramp21', 'Ramp21', 'Ramp22', 'Ramp22', 'Ramp23', 'Ramp23', 'Ramp24', 'Ramp24', 'Ramp24', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload']

# %%
from utils.csv_utils import get_data
# Out:
# ['eid', '3-0.0', '3-1.0', '3-2.0', '3-3.0', '4-0.0', '4-1.0', '4-2.0', '4-3.0', '5-0.0', '5-1.0', '5-2.0', '5-3.0', '6-0.0', '6-1.0', '6-2.0', '6-3.0', '19-0.0', '21-0.0', '21-1.0', '21-2.0', '21-3.0', '31-0.0', '34-0.0', '36-0.0', '36-1.0', '36-2.0', '36-3.0', '37-0.0', '37-1.0', '37-2.0', '37-3.0', '38-0.0', '38-1.0', '38-2.0', '38-3.0', '39-0.0', '39-1.0', '39-2.0', '39-3.0', '40-0.0', '40-1.0', '40-2.0', '40-3.0', '41-0.0', '41-1.0', '41-2.0', '41-3.0', '42-0.0', '42-1.0', '42-2.0', '42-3.0', '43-0.0', '43-1.0', '43-2.0', '43-3.0', '44-0.0', '44-1.0', '44-2.0', '44-3.0', '45-0.0', '45-1.0', '45-2.0', '45-3.0', '46-0.0', '46-1.0', '46-2.0', '46-3.0', '47-0.0', '47-1.0', '47-2.0', '47-3.0', '48-0.0', '48-1.0', '48-2.0', '48-3.0', '49-0.0', '49-1.0', '49-2.0', '49-3.0', '50-0.0', '50-1.0', '50-2.0', '50-3.0', '51-0.0', '51-1.0', '51-2.0', '51-3.0', '52-0.0', '53-0.0', '53-1.0', '53-2.0', '53-3.0', '54-0.0', '54-1.0', '54-2.0', '54-3.0', '55-0.0', '55-1.0', '55-2.0', '55-3.0', '77-0.0', '78-0.0', '84-0.0', '84-0.1', '84-0.2', '84-0.3', '84-0.4', '84-0.5', '84-1.0', '84-1.1', '84-1.2', '84-1.3', '84-1.4', '84-1.5', '84-2.0', '84-2.1', '84-2.2', '84-2.3', '84-2.4', '84-2.5', '84-3.0', '84-3.1', '84-3.2', '84-3.3', '84-3.4', '84-3.5', '87-0.0', '87-0.1', '87-0.2', '87-0.3', '87-0.4', '87-0.5', '87-0.6', '87-0.7', '87-0.8', '87-0.9', '87-0.10', '87-0.11', '87-0.12', '87-0.13', '87-0.14', '87-0.15', '87-0.16', '87-0.17', '87-0.18', '87-0.19', '87-0.20', '87-0.21', '87-0.22', '87-0.23', '87-0.24', '87-0.25', '87-0.26', '87-0.27', '87-0.28', '87-0.29', '87-0.30', '87-0.31', '87-0.32', '87-0.33', '87-1.0', '87-1.1', '87-1.2', '87-1.3', '87-1.4', '87-1.5', '87-1.6', '87-1.7', '87-1.8', '87-1.9', '87-1.10', '87-1.11', '87-1.12', '87-1.13', '87-1.14', '87-1.15', '87-1.16', '87-1.17', '87-1.18', '87-1.19', '87-1.20', '87-1.21', '87-1.22', '87-1.23', '87-1.24', '87-1.25', '87-1.26', '87-1.27', '87-1.28', '87-1.29', '87-1.30', '87-1.31', '87-1.32', '87-1.33', '87-2.0', '87-2.1', '87-2.2', '87-2.3', '87-2.4', '87-2.5', '87-2.6', '87-2.7', '87-2.8', '87-2.9', '87-2.10', '87-2.11', '87-2.12', '87-2.13', '87-2.14', '87-2.15', '87-2.16', '87-2.17', '87-2.18', '87-2.19', '87-2.20', '87-2.21', '87-2.22', '87-2.23', '87-2.24', '87-2.25', '87-2.26', '87-2.27', '87-2.28', '87-2.29', '87-2.30', '87-2.31', '87-2.32', '87-2.33', '87-3.0', '87-3.1', '87-3.2', '87-3.3', '87-3.4', '87-3.5', '87-3.6', '87-3.7', '87-3.8', '87-3.9', '87-3.10', '87-3.11', '87-3.12', '87-3.13', '87-3.14', '87-3.15', '87-3.16', '87-3.17', '87-3.18', '87-3.19', '87-3.20', '87-3.21', '87-3.22', '87-3.23', '87-3.24', '87-3.25', '87-3.26', '87-3.27', '87-3.28', '87-3.29', '87-3.30', '87-3.31', '87-3.32', '87-3.33', '92-0.0', '92-0.1', '92-0.2', '92-0.3', '92-0.4', '92-0.5', '92-0.6', '92-0.7', '92-0.8', '92-0.9', '92-0.10', '92-0.11', '92-0.12', '92-0.13', '92-0.14', '92-0.15', '92-0.16', '92-0.17', '92-0.18', '92-0.19', '92-0.20', '92-0.21', '92-0.22', '92-0.23', '92-0.24', '92-0.25', '92-0.26', '92-0.27', '92-0.28', '92-0.29', '92-0.30', '92-0.31', '92-1.0', '92-1.1', '92-1.2', '92-1.3', '92-1.4', '92-1.5', '92-1.6', '92-1.7', '92-1.8', '92-1.9', '92-1.10', '92-1.11', '92-1.12', '92-1.13', '92-1.14', '92-1.15', '92-1.16', '92-1.17', '92-1.18', '92-1.19', '92-1.20', '92-1.21', '92-1.22', '92-1.23', '92-1.24', '92-1.25', '92-1.26', '92-1.27', '92-1.28', '92-1.29', '92-1.30', '92-1.31', '92-2.0', '92-2.1', '92-2.2', '92-2.3', '92-2.4', '92-2.5', '92-2.6', '92-2.7', '92-2.8', '92-2.9', '92-2.10', '92-2.11', '92-2.12', '92-2.13', '92-2.14', '92-2.15', '92-2.16', '92-2.17', '92-2.18', '92-2.19', '92-2.20', '92-2.21', '92-2.22', '92-2.23', '92-2.24', '92-2.25', '92-2.26', '92-2.27', '92-2.28', '92-2.29', '92-2.30', '92-2.31', '92-3.0', '92-3.1', '92-3.2', '92-3.3', '92-3.4', '92-3.5', '92-3.6', '92-3.7', '92-3.8', '92-3.9', '92-3.10', '92-3.11', '92-3.12', '92-3.13', '92-3.14', '92-3.15', '92-3.16', '92-3.17', '92-3.18', '92-3.19', '92-3.20', '92-3.21', '92-3.22', '92-3.23', '92-3.24', ' ...

# %%
columns_5986 = [f"5986-0.{i}" for i in range(0, 113)]

df = get_data(columns_5986)
print(df)
# Out:
#          eid  5986-0.0  5986-0.1  5986-0.2  5986-0.3  5986-0.4  5986-0.5  \
# 0    1000016      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 1    1000021      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 2    1000033      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 3    1000049      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 4    1000057      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# ..       ...       ...       ...       ...       ...       ...       ...
# 717  6026408      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 718  6026414      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 719  6026429      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 720  6026431      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 721  6026447      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
#
#      5986-0.6  5986-0.7  5986-0.8  ...  5986-0.103  5986-0.104  5986-0.105  \
# 0        <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 1        <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 2        <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 3        <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 4        <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# ..        ...       ...       ...  ...         ...         ...         ...
# 717      <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 718      <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 719      <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 720      <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
# 721      <NA>      <NA>      <NA>  ...        <NA>        <NA>        <NA>
#
#      5986-0.106  5986-0.107  5986-0.108  5986-0.109  5986-0.110  5986-0.111  \
# 0          <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 1          <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 2          <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 3          <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 4          <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# ..          ...         ...         ...         ...         ...         ...
# 717        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 718        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 719        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 720        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 721        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
#
#      5986-0.112
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# ..          ...
# 717        <NA>
# 718        <NA>
# 719        <NA>
# 720        <NA>
# 721        <NA>
#
# [502367 rows x 114 columns]

# %%
df.to_csv("../../data/5986.csv", index=False)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f89c27bf220>>
# Traceback (most recent call last):
#   File "/work/users/y/u/yuukias/env_conda/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# [(1000205,), (1000239,), (1000361,), (1000400,), (1000458,), (1000587,), (1000659,), (1000668,), (1000677,), (1000737,), (1000779,), (1000788,), (1000814,), (1000928,), (1000991,), (1001064,), (1001125,), (1001132,), (1001233,), (1001249,), (1001298,), (1001319,), (1001324,), (1001346,), (1001786,), (1001806,), (1001894,), (1001978,), (1002007,), (1002054,), (1002252,), (1002260,), (1002485,), (1002613,), (1002622,), (1002778,), (1002863,), (1002908,), (1002914,), (1002947,), (1002950,), (1003023,), (1003041,), (1003094,), (1003262,), (1003273,), (1003286,), (1003295,), (1003328,), (1003448,), (1003454,), (1003483,), (1003534,), (1003555,), (1003590,), (1003637,), (1003727,), (1003792,), (1003821,), (1003849,), (1003870,), (1003924,), (1003952,), (1003975,), (1004026,), (1004090,), (1004149,), (1004276,), (1004318,), (1004371,), (1004429,), (1004447,), (1004506,), (1004601,), (1004624,), (1004638,), (1004709,), (1004744,), (1004869,), (1004902,), (1005072,), (1005437,), (1005550,), (1005625,), (1005758,), (1005769,), (1005801,), (1005904,), (1005916,), (1005957,), (1006097,), (1006256,), (1006347,), (1006416,), (1006465,), (1006564,), (1006634,), (1006642,), (1006655,), (1006667,), (1006787,), (1006899,), (1006927,), (1006971,), (1007215,), (1007237,), (1007251,), (1007264,), (1007322,), (1007358,), (1007397,), (1007426,), (1007563,), (1007572,), (1007604,), (1007633,), (1007670,), (1007682,), (1007723,), (1007827,), (1007948,), (1007961,), (1007976,), (1008019,), (1008060,), (1008236,), (1008258,), (1008320,), (1008364,), (1008453,), (1008484,), (1008521,), (1008617,), (1008635,), (1008656,), (1008754,), (1008811,), (1008867,), (1008923,), (1008985,), (1009018,), (1009084,), (1009163,), (1009268,), (1009277,), (1009311,), (1009378,), (1009419,), (1009561,), (1009650,), (1009704,), (1009815,), (1009896,), (1009936,), (1009945,), (1010047,), (1010187,), (1010220,), (1010251,), (1010264,), (1010296,), (1010556,), (1010563,), (1010670,), (1010839,), (1010866,), (1010884,), (1010925,), (1010961,), (1011012,), (1011030,), (1011145,), (1011407,), (1011425,), (1011555,), (1011651,), (1011688,), (1011705,), (1011753,), (1012106,), (1012263,), (1012308,), (1012350,), (1012416,), (1012470,), (1012520,), (1012543,), (1012634,), (1012738,), (1012793,), (1012825,), (1012927,), (1012940,), (1012984,), (1013004,), (1013178,), (1013307,), (1013348,), (1013413,), (1013481,), (1013524,), (1013630,), (1013779,), (1013796,), (1013980,), (1013991,), (1014024,), (1014046,), (1014186,), (1014200,), (1014320,), (1014453,), (1014471,), (1014565,), (1014748,), (1014855,), (1014867,), (1014977,), (1015025,), (1015032,), (1015076,), (1015083,), (1015151,), (1015179,), (1015224,), (1015304,), (1015370,), (1015494,), (1015571,), (1015755,), (1015778,), (1015790,), (1015835,), (1015908,), (1015931,), (1016042,), (1016104,), (1016182,), (1016198,), (1016210,), (1016327,), (1016339,), (1016392,), (1016447,), (1016506,), (1016530,), (1016624,), (1016709,), (1016763,), (1016772,), (1016791,), (1016964,), (1017005,), (1017040,), (1017092,), (1017268,), (1017311,), (1017390,), (1017475,), (1017507,), (1017510,), (1017525,), (1017770,), (1017798,), (1017864,), (1017969,), (1017974,), (1018028,), (1018035,), (1018044,), (1018056,), (1018184,), (1018211,), (1018267,), (1018394,), (1018451,), (1018496,), (1018508,), (1018562,), (1018586,), (1018607,), (1018769,), (1018852,), (1018904,), (1018921,), (1018949,), (1019043,), (1019064,), (1019088,), (1019463,), (1019480,), (1019500,), (1019513,), (1019597,), (1019605,), (1019639,), (1019684,), (1019708,), (1019714,), (1019795,), (1019841,), (1019903,), (1019942,), (1019955,), (1020046,), (1020131,), (1020213,), (1020439,), (1020533,), (1020549,), (1020598,), (1020644,), (1020691,), (1020725,), (1020930,), (1020941,), (1020994,), (1021224,), (1021238,), (1021316,), (1021333,), (1021398,), (1021592,), (1021613,), (1021658,), (1021674,), (1021767,), (1021809,), (1021872,), (1021908,), (1021973,), (1022015,), (1022043,), (10 ...

# %%
query_sql = f"""
SELECT eid
FROM {processed_table_name}
"""

eids = cursor.execute(query_sql).fetchall()
print(eids)
eids = [eid[0] for eid in eids]
# Out:
# [(1000205,), (1000239,), (1000361,), (1000400,), (1000458,), (1000587,), (1000659,), (1000668,), (1000677,), (1000737,), (1000779,), (1000788,), (1000814,), (1000928,), (1000991,), (1001064,), (1001125,), (1001132,), (1001233,), (1001249,), (1001298,), (1001319,), (1001324,), (1001346,), (1001786,), (1001806,), (1001894,), (1001978,), (1002007,), (1002054,), (1002252,), (1002260,), (1002485,), (1002613,), (1002622,), (1002778,), (1002863,), (1002908,), (1002914,), (1002947,), (1002950,), (1003023,), (1003041,), (1003094,), (1003262,), (1003273,), (1003286,), (1003295,), (1003328,), (1003448,), (1003454,), (1003483,), (1003534,), (1003555,), (1003590,), (1003637,), (1003727,), (1003792,), (1003821,), (1003849,), (1003870,), (1003924,), (1003952,), (1003975,), (1004026,), (1004090,), (1004149,), (1004276,), (1004318,), (1004371,), (1004429,), (1004447,), (1004506,), (1004601,), (1004624,), (1004638,), (1004709,), (1004744,), (1004869,), (1004902,), (1005072,), (1005437,), (1005550,), (1005625,), (1005758,), (1005769,), (1005801,), (1005904,), (1005916,), (1005957,), (1006097,), (1006256,), (1006347,), (1006416,), (1006465,), (1006564,), (1006634,), (1006642,), (1006655,), (1006667,), (1006787,), (1006899,), (1006927,), (1006971,), (1007215,), (1007237,), (1007251,), (1007264,), (1007322,), (1007358,), (1007397,), (1007426,), (1007563,), (1007572,), (1007604,), (1007633,), (1007670,), (1007682,), (1007723,), (1007827,), (1007948,), (1007961,), (1007976,), (1008019,), (1008060,), (1008236,), (1008258,), (1008320,), (1008364,), (1008453,), (1008484,), (1008521,), (1008617,), (1008635,), (1008656,), (1008754,), (1008811,), (1008867,), (1008923,), (1008985,), (1009018,), (1009084,), (1009163,), (1009268,), (1009277,), (1009311,), (1009378,), (1009419,), (1009561,), (1009650,), (1009704,), (1009815,), (1009896,), (1009936,), (1009945,), (1010047,), (1010187,), (1010220,), (1010251,), (1010264,), (1010296,), (1010556,), (1010563,), (1010670,), (1010839,), (1010866,), (1010884,), (1010925,), (1010961,), (1011012,), (1011030,), (1011145,), (1011407,), (1011425,), (1011555,), (1011651,), (1011688,), (1011705,), (1011753,), (1012106,), (1012263,), (1012308,), (1012350,), (1012416,), (1012470,), (1012520,), (1012543,), (1012634,), (1012738,), (1012793,), (1012825,), (1012927,), (1012940,), (1012984,), (1013004,), (1013178,), (1013307,), (1013348,), (1013413,), (1013481,), (1013524,), (1013630,), (1013779,), (1013796,), (1013980,), (1013991,), (1014024,), (1014046,), (1014186,), (1014200,), (1014320,), (1014453,), (1014471,), (1014565,), (1014748,), (1014855,), (1014867,), (1014977,), (1015025,), (1015032,), (1015076,), (1015083,), (1015151,), (1015179,), (1015224,), (1015304,), (1015370,), (1015494,), (1015571,), (1015755,), (1015778,), (1015790,), (1015835,), (1015908,), (1015931,), (1016042,), (1016104,), (1016182,), (1016198,), (1016210,), (1016327,), (1016339,), (1016392,), (1016447,), (1016506,), (1016530,), (1016624,), (1016709,), (1016763,), (1016772,), (1016791,), (1016964,), (1017005,), (1017040,), (1017092,), (1017268,), (1017311,), (1017390,), (1017475,), (1017507,), (1017510,), (1017525,), (1017770,), (1017798,), (1017864,), (1017969,), (1017974,), (1018028,), (1018035,), (1018044,), (1018056,), (1018184,), (1018211,), (1018267,), (1018394,), (1018451,), (1018496,), (1018508,), (1018562,), (1018586,), (1018607,), (1018769,), (1018852,), (1018904,), (1018921,), (1018949,), (1019043,), (1019064,), (1019088,), (1019463,), (1019480,), (1019500,), (1019513,), (1019597,), (1019605,), (1019639,), (1019684,), (1019708,), (1019714,), (1019795,), (1019841,), (1019903,), (1019942,), (1019955,), (1020046,), (1020131,), (1020213,), (1020439,), (1020533,), (1020549,), (1020598,), (1020644,), (1020691,), (1020725,), (1020930,), (1020941,), (1020994,), (1021224,), (1021238,), (1021316,), (1021333,), (1021398,), (1021592,), (1021613,), (1021658,), (1021674,), (1021767,), (1021809,), (1021872,), (1021908,), (1021973,), (1022015,), (1022043,), (10 ...

# %%
# select all rows from df with matching eids
df_new = df[df["eid"].isin(eids)]
print(df_new.shape)
df = df_new
# Out:
# (77888, 114)

# %%
df.head()
# Out:
#         eid  5986-0.0  5986-0.1  5986-0.2  5986-0.3  5986-0.4  5986-0.5  \
# 19  1000205         0        15         0         4        14        29
# 22  1000239         0        15         0         4        14        29
# 35  1000361         0        15         0        14        29        33
# 39  1000400         1        15         0         4        14        29
# 44  1000458         0        15         0         9        14        29
#
#     5986-0.6  5986-0.7  5986-0.8  ...  5986-0.103  5986-0.104  5986-0.105  \
# 19        44        59        74  ...        <NA>        <NA>        <NA>
# 22        38        44        59  ...        <NA>        <NA>        <NA>
# 35        44        54        59  ...        <NA>        <NA>        <NA>
# 39        44        59        74  ...        <NA>        <NA>        <NA>
# 44        44        59        74  ...        <NA>        <NA>        <NA>
#
#     5986-0.106  5986-0.107  5986-0.108  5986-0.109  5986-0.110  5986-0.111  \
# 19        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 22        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 35        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 39        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 44        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
#
#     5986-0.112
# 19        <NA>
# 22        <NA>
# 35        <NA>
# 39        <NA>
# 44        <NA>
#
# [5 rows x 114 columns]

# %%
df[df["eid"] == int(ID)]
# Out:
#          eid  5986-0.0  5986-0.1  5986-0.2  5986-0.3  5986-0.4  5986-0.5  \
# 240  1038535         0        15         0         9        14        29
#
#      5986-0.6  5986-0.7  5986-0.8  ...  5986-0.103  5986-0.104  5986-0.105  \
# 240        44        59        74  ...        <NA>        <NA>        <NA>
#
#      5986-0.106  5986-0.107  5986-0.108  5986-0.109  5986-0.110  5986-0.111  \
# 240        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
#
#      5986-0.112
# 240        <NA>
#
# [1 rows x 114 columns]

# %%
import pandas as pd
phase_time = list(df[df["eid"] == int(ID)].drop(columns=["eid"]).values[0])
phase_time = [time for time in phase_time if not pd.isna(time)]

stage_name = ["Ramp" if "Ramp" in name else name for name in stage_name]

# %%
print(len(phase_name), phase_name)
print(len(stage_name), stage_name)
print(len(phase_time), phase_time)
# Out:
# 81 ['Pretest', 'Pretest', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Exercise', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest', 'Rest']
# 81 ['Steady', 'Steady', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Constant', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Ramp', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload', 'Noload']
# 81 [0, 15, 0, 9, 14, 29, 44, 59, 74, 89, 104, 119, 120, 124, 130, 134, 140, 144, 149, 150, 154, 160, 164, 170, 174, 179, 180, 184, 190, 194, 200, 200, 204, 209, 210, 214, 220, 224, 230, 234, 239, 240, 243, 244, 250, 254, 260, 264, 269, 270, 274, 280, 284, 290, 294, 296, 299, 300, 304, 310, 314, 320, 320, 324, 329, 330, 334, 340, 344, 350, 354, 359, 360, 4, 9, 14, 29, 44, 54, 59, 60]

# %%
phase_name = np.array(phase_name)
stage_name = np.array(stage_name)
phase_time = np.array(phase_time)

# count time for each stage
steady_time = np.max(phase_time[stage_name == "Steady"])
constant_time = np.max(phase_time[stage_name == "Constant"])
ramp_time = np.max(phase_time[stage_name == "Ramp"]) - constant_time
noload_time = np.max(phase_time[stage_name == "Noload"])

print(steady_time, constant_time, ramp_time, noload_time)
print(steady_time / 60, constant_time / 60, ramp_time / 60, noload_time / 60)  # unit: minutes
# Out:
# 15 120 240 60
# 0.25 2.0 4.0 1.0

# %%
15 + 120 + 240 + 60
# Out:
# 435

# %%
import neurokit2 as nk

signal_full = np.array(ecg_processor.get_signals('2'))
print(len(signal_full) / SAMPLING_RATE)   # unit: seconds
# Out:
# 433.0

# %%
import importlib
module = importlib.import_module('utils.ecg_processor')
importlib.reload(module)

from utils.ecg_processor import ECG_Reader

# %%
ecg_reader = ECG_Reader(os.path.join(ECG_folder, f"{ID}_6025_0_0.xml"))
signals_all = ecg_reader.get_lead_signals()
print(len(signals_all['I']) / SAMPLING_RATE)
print(len(signals_all['2']) / SAMPLING_RATE)
print(len(signals_all['3']) / SAMPLING_RATE)
# Out:
# 649501
# 649500
# 433.0
# 433.0
# 433.0

# %% [markdown]
# TODO: Merge csv with database.

# %% [markdown]
# Eventually, we determine the appropriate region of ECG signal to be used for the analysis.

# %%
signal_rest = signal_full[-noload_time * SAMPLING_RATE:]
print(len(signal_rest) / SAMPLING_RATE)

peaks, info = nk.ecg_process(signal_rest, sampling_rate=SAMPLING_RATE)
hrv_nonlinear = nk.hrv_nonlinear(peaks, sampling_rate=SAMPLING_RATE, show=True)
hrv_nonlinear
# Out:
# 60.0
# /work/users/y/u/yuukias/env_conda/lib/python3.9/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
#        HRV_SD1      HRV_SD2  HRV_SD1SD2         HRV_S   HRV_CSI   HRV_CVI  \
# 0  1380.805477  1222.452171    1.129537  5.302910e+06  0.885318  7.431484
#
#    HRV_CSI_Modified   HRV_PIP  HRV_IALS  HRV_PSS  ...  HRV_SampEn  HRV_ShanEn  \
# 0       4329.036452  0.558824  0.606061      0.8  ...    1.299283    4.969816
#
#    HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD   HRV_HFD   HRV_KFD  \
# 0     1.530944       0.0        0.0         0.0  0.890118  2.042809  3.529675
#
#     HRV_LZC
# 0  1.496313
#
# [1 rows x 47 columns]

# %%
signal_constant = signal_full[steady_time*SAMPLING_RATE : (steady_time + constant_time)*SAMPLING_RATE]
print(len(signal_constant) / SAMPLING_RATE)

peaks, info = nk.ecg_process(signal_constant, sampling_rate=SAMPLING_RATE)
hrv_nonlinear = nk.hrv_nonlinear(peaks, sampling_rate=SAMPLING_RATE, show=True)
hrv_nonlinear
# Out:
# 120.0
# /work/users/y/u/yuukias/env_conda/lib/python3.9/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
#      HRV_SD1     HRV_SD2  HRV_SD1SD2         HRV_S   HRV_CSI   HRV_CVI  \
# 0  719.82806  921.323618    0.781298  2.083487e+06  1.279922  7.025761
#
#    HRV_CSI_Modified   HRV_PIP  HRV_IALS  HRV_PSS  ...  HRV_SampEn  HRV_ShanEn  \
# 0        4716.88869  0.721154  0.735294     0.92  ...    1.264797    6.162227
#
#    HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD   HRV_HFD   HRV_KFD  \
# 0     1.384017  1.237447   1.141522    1.494545  1.049624  1.965043  2.670348
#
#     HRV_LZC
# 0  1.030837
#
# [1 rows x 47 columns]
